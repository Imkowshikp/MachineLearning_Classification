# %% [markdown]
# # Kowshik P
#
# ## Classification Assignment submitted on 26-Apr-2022
# ## ------------------------------------------------------------------------
# ## Model Implemented - Naive-Bayes Classification
# ## Model 1 - GaussianNB : 0.89
# ## Model 2 - MultinomialNB : 0.76
# ## Model 3 - ComplementNB : 0.76
# ## Model 4 - BernoulliNB : 0.96
# ## Model 5 - CategoricalNB : Index error
# ## Performance - Average
# ## ------------------------------------------------------------------------

# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as mat;

# %%
clientInformation = pd.read_csv("fraud.csv");

clientInformation
# Out:
#        step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 0         1   PAYMENT     9839.64      170136.00       160296.36
# 1         1   PAYMENT     1864.28       21249.00        19384.72
# 2         1   PAYMENT    11668.14       41554.00        29885.86
# 3         1   PAYMENT     7817.71       53860.00        46042.29
# 4         1   PAYMENT     7107.77      183195.00       176087.23
# ...     ...       ...         ...            ...             ...
# 16421   743  CASH_OUT   339682.13      339682.13            0.00
# 16422   743  TRANSFER  6311409.28     6311409.28            0.00
# 16423   743  CASH_OUT  6311409.28     6311409.28            0.00
# 16424   743  TRANSFER   850002.52      850002.52            0.00
# 16425   743  CASH_OUT   850002.52      850002.52            0.00
#
#        oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                0.00            0.00        0               0
# ...

# %%
clientInformation.shape
# Out:
# (16426, 9)

# %%
clientInformation = pd.get_dummies(clientInformation, drop_first = True);

clientInformation
# Out:
#        step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         1     9839.64      170136.00       160296.36            0.00
# 1         1     1864.28       21249.00        19384.72            0.00
# 2         1    11668.14       41554.00        29885.86            0.00
# 3         1     7817.71       53860.00        46042.29            0.00
# 4         1     7107.77      183195.00       176087.23            0.00
# ...     ...         ...            ...             ...             ...
# 16421   743   339682.13      339682.13            0.00            0.00
# 16422   743  6311409.28     6311409.28            0.00            0.00
# 16423   743  6311409.28     6311409.28            0.00        68488.84
# 16424   743   850002.52      850002.52            0.00            0.00
# 16425   743   850002.52      850002.52            0.00      6510099.11
#
#        newbalanceDest  isFraud  isFlaggedFraud  type_CASH_OUT  type_DEBIT  \
# ...

# %%
clientInformation = clientInformation.drop("isFlaggedFraud", axis = 1);

clientInformation
# Out:
#        step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         1     9839.64      170136.00       160296.36            0.00
# 1         1     1864.28       21249.00        19384.72            0.00
# 2         1    11668.14       41554.00        29885.86            0.00
# 3         1     7817.71       53860.00        46042.29            0.00
# 4         1     7107.77      183195.00       176087.23            0.00
# ...     ...         ...            ...             ...             ...
# 16421   743   339682.13      339682.13            0.00            0.00
# 16422   743  6311409.28     6311409.28            0.00            0.00
# 16423   743  6311409.28     6311409.28            0.00        68488.84
# 16424   743   850002.52      850002.52            0.00            0.00
# 16425   743   850002.52      850002.52            0.00      6510099.11
#
#        newbalanceDest  isFraud  type_CASH_OUT  type_DEBIT  type_PAYMENT  \
# ...

# %%
independentVariable = clientInformation[["step", "amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "type_CASH_OUT", "type_DEBIT", "type_PAYMENT", "type_TRANSFER"]];

independentVariable
# Out:
#        step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         1     9839.64      170136.00       160296.36            0.00
# 1         1     1864.28       21249.00        19384.72            0.00
# 2         1    11668.14       41554.00        29885.86            0.00
# 3         1     7817.71       53860.00        46042.29            0.00
# 4         1     7107.77      183195.00       176087.23            0.00
# ...     ...         ...            ...             ...             ...
# 16421   743   339682.13      339682.13            0.00            0.00
# 16422   743  6311409.28     6311409.28            0.00            0.00
# 16423   743  6311409.28     6311409.28            0.00        68488.84
# 16424   743   850002.52      850002.52            0.00            0.00
# 16425   743   850002.52      850002.52            0.00      6510099.11
#
#        newbalanceDest  type_CASH_OUT  type_DEBIT  type_PAYMENT  type_TRANSFER
# ...

# %%
dependentVariable = clientInformation[["isFraud"]];

dependentVariable
# Out:
#        isFraud
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 16421        1
# 16422        1
# 16423        1
# 16424        1
# 16425        1
#
# [16426 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split;

x_train, x_test, y_train, y_test = train_test_split(independentVariable, dependentVariable, test_size = 1/3, random_state = 0);

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
#from sklearn.preprocessing import StandardScaler;

#standardization = StandardScaler();

#x_train = standardization.fit_transform(x_train);

#x_test = standardization.transform(x_test);

# %% [markdown]
# # GaussianNB
# ## The best performance is 1

# %%
from sklearn.naive_bayes import GaussianNB;

naiveBayesClassifer = GaussianNB();

naiveBayesClassifer.fit(x_train, y_train);
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = naiveBayesClassifer.predict(x_test);

# %%
from sklearn.metrics import confusion_matrix;

naiveBayesClassiferConfusionMatrix = confusion_matrix(y_test, y_pred);

print(naiveBayesClassiferConfusionMatrix);
# Out:
# [[2677   45]
#  [ 563 2191]]

# %%
from sklearn.metrics import classification_report;

naiveBayesClassifierReport = classification_report(y_test, y_pred);

print(naiveBayesClassifierReport);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      2722
#            1       0.98      0.80      0.88      2754
#
#     accuracy                           0.89      5476
#    macro avg       0.90      0.89      0.89      5476
# weighted avg       0.90      0.89      0.89      5476

# %% [markdown]
# # MultinomialNB
# ## The best performance is 1

# %%
from sklearn.naive_bayes import MultinomialNB;

naiveBayesClassifierMultinominal = MultinomialNB();

naiveBayesClassifierMultinominal.fit(x_train, y_train);
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = naiveBayesClassifierMultinominal.predict(x_test);

# %%
from sklearn.metrics import confusion_matrix;

naiveBayesMultinominalNBCofusionMatrix = confusion_matrix(y_test, y_pred);

print(naiveBayesMultinominalNBCofusionMatrix);
# Out:
# [[1687 1035]
#  [ 291 2463]]

# %%
from sklearn.metrics import classification_report;

naiveBayesMultinominalNBClassificationReport = classification_report(y_test, y_pred);

print(naiveBayesMultinominalNBClassificationReport);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.62      0.72      2722
#            1       0.70      0.89      0.79      2754
#
#     accuracy                           0.76      5476
#    macro avg       0.78      0.76      0.75      5476
# weighted avg       0.78      0.76      0.75      5476

# %% [markdown]
# # ComplementNB
# ## The best performance is 1

# %%
from sklearn.naive_bayes import ComplementNB;

naiveBayesClassifierComplementNB = ComplementNB();

naiveBayesClassifierComplementNB.fit(x_train, y_train);
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = naiveBayesClassifierComplementNB.predict(x_test);

# %%
from sklearn.metrics import confusion_matrix;

naiveBayesComplementNBconfusionMatrix = confusion_matrix(y_test, y_pred);

print(naiveBayesComplementNBconfusionMatrix);
# Out:
# [[1687 1035]
#  [ 291 2463]]

# %%
from sklearn.metrics import classification_report;

naiveBayesComplementNBclassificationReport = classification_report(y_test, y_pred);

print(naiveBayesComplementNBclassificationReport);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.62      0.72      2722
#            1       0.70      0.89      0.79      2754
#
#     accuracy                           0.76      5476
#    macro avg       0.78      0.76      0.75      5476
# weighted avg       0.78      0.76      0.75      5476

# %% [markdown]
# # BernoulliNB
# ## The best performance is 1

# %%
from sklearn.naive_bayes import BernoulliNB;

naiveBayesClassifierBernoulliNB = BernoulliNB();

naiveBayesClassifierBernoulliNB.fit(x_train, y_train);
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = naiveBayesClassifierBernoulliNB.predict(x_test);

# %%
from sklearn.metrics import confusion_matrix;

naiveBayesBernoulliNBconfusionMatrix = confusion_matrix(y_test, y_pred);

print(naiveBayesBernoulliNBconfusionMatrix);
# Out:
# [[2545  177]
#  [  64 2690]]

# %%
from sklearn.metrics import classification_report;

naiveBayesBernoulliNBclassificationReport = classification_report(y_test, y_pred);

print(naiveBayesBernoulliNBclassificationReport);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95      2722
#            1       0.94      0.98      0.96      2754
#
#     accuracy                           0.96      5476
#    macro avg       0.96      0.96      0.96      5476
# weighted avg       0.96      0.96      0.96      5476

# %% [markdown]
# # CategoricalNB
# ## The best performance is 1

# %%
from sklearn.preprocessing import StandardScaler;

standardization = StandardScaler();

x_train = standardization.fit_transform(x_train);

x_test = standardization.transform(x_test);

# %%
from sklearn.naive_bayes import CategoricalNB;

naiveBayesClassifierCategoricalNB = CategoricalNB(fit_prior = True);

naiveBayesClassifierCategoricalNB.fit(x_train, y_train);
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = naiveBayesClassifierCategoricalNB.predict(x_test);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8096\4288935407.py in <module>
# ----> 1 y_pred = naiveBayesClassifierCategoricalNB.predict(x_test);
#
# ~\Anaconda3\envs\virtualml\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      81         check_is_fitted(self)
#      82         X = self._check_X(X)
# ---> 83         jll = self._joint_log_likelihood(X)
#      84         return self.classes_[np.argmax(jll, axis=1)]
#      85
#
# ~\Anaconda3\envs\virtualml\lib\site-packages\sklearn\naive_bayes.py in _joint_log_likelihood(self, X)
#    1459         for i in range(self.n_features_in_):
#    1460             indices = X[:, i]
# -> 1461             jll += self.feature_log_prob_[i][:, indices].T
#    1462         total_ll = jll + self.class_log_prior_
#    1463         return total_ll
#
# ...
